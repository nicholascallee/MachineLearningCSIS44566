# %% [markdown]
# ##### Assignment 5 - Linear Regression

# %% [markdown]
# ## Part 1 - Read your data frame.
# The CSV file is "fifa_data.csv"

# %%
# Your code here
import pandas as pd
data = pd.read_csv("fifa_data.csv")

print(data.info())

data.drop(labels=["Loaned From", "Club", "Joined"], axis='columns', inplace=True)
data.dropna(axis='index', how='any', inplace=True)
print(data)

data.hist(bins=20)
print(data.head(n=10))
data.corr()

print(data.keys())
print(data.info())
print()
print(data["Nationality"].value_counts())

from pandas.plotting import scatter_matrix


def euro_converter(string):
    unit = string[0:1]
    value = string[1:len(string)-1]
    multiplier = string[-1]
    if multiplier =="0": return 0
    
    # print(unit, value, multiplier)
    value = float(value)
    if multiplier=="M": value *= 1000000
    if multiplier=="K": value *= 1000
    return value

data["Numeric Wage"] = data["Wage"].map(euro_converter)#maping new feature

compare = ["Overall", "Potential", "HeadingAccuracy", "Age", "Skill Moves", "Numeric Wage"]
scatter_matrix(data[compare])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 89 columns):
# Unnamed: 0                  18207 non-null int64
# ID                          18207 non-null int64
# Name                        18207 non-null object
# Age                         18207 non-null int64
# Photo                       18207 non-null object
# Nationality                 18207 non-null object
# Flag                        18207 non-null object
# Overall                     18207 non-null int64
# Potential                   18207 non-null int64
# Club                        17966 non-null object
# Club Logo                   18207 non-null object
# Value                       18207 non-null object
# Wage                        18207 non-null object
# Special                     18207 non-null int64
# Preferred Foot              18159 non-null object
# International Reputation    18159 non-null float64
# Weak Foot                   18159 non-null float64
# ...

# %% [markdown]
# ## Part 2 - Display info
# Take a look at the information.  Note any features that are missing values.  Note any features that are objects, but could be numerical

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14743 entries, 0 to 18206
# Data columns (total 87 columns):
# Unnamed: 0                  14743 non-null int64
# ID                          14743 non-null int64
# Name                        14743 non-null object
# Age                         14743 non-null int64
# Photo                       14743 non-null object
# Nationality                 14743 non-null object
# Flag                        14743 non-null object
# Overall                     14743 non-null int64
# Potential                   14743 non-null int64
# Club Logo                   14743 non-null object
# Value                       14743 non-null object
# Wage                        14743 non-null object
# Special                     14743 non-null int64
# Preferred Foot              14743 non-null object
# International Reputation    14743 non-null float64
# Weak Foot                   14743 non-null float64
# Skill Moves                 14743 non-null float64
# ...

# %% [markdown]
# ### _Notes_
# value and wage are objects that could be ints or floats
# same with these
# Height                      14743 non-null object
# Weight                      14743 non-null object
# LS                          14743 non-null object
# ST                          14743 non-null object
# RS                          14743 non-null object
# LW                          14743 non-null object
# LF                          14743 non-null object
# CF                          14743 non-null object
# RF                          14743 non-null object
# RW                          14743 non-null object
# LAM                         14743 non-null object
# CAM                         14743 non-null object
# RAM                         14743 non-null object
# LM                          14743 non-null object
# LCM                         14743 non-null object
# CM                          14743 non-null object
# RCM                         14743 non-null object
# RM                          14743 non-null object
# LWB                         14743 non-null object
# LDM                         14743 non-null object
# CDM                         14743 non-null object
# RDM                         14743 non-null object
# RWB                         14743 non-null object
# LB                          14743 non-null object
# LCB                         14743 non-null object
# CB                          14743 non-null object
# RCB                         14743 non-null object
# RB

# %% [markdown]
# ## Part 3a - Remove columns (features)
# Refer to data_cleaning in the DataFrames directory
#
# The "Loaned From" data feature is sparse and does not help us.
#
# Remove that column from your data frame.

# %%
# this part is already done on part 1. see above code for this part. 

#data.drop(label = ["Loaned From"]axis = "column")

# %% [markdown]
# ## Part 3b - Remove rows (data instances)
# Refer to data_cleaning in the DataFrames directory
#
# For now, go ahead and remove any instance that is missing any data value.

# %%
# all features are non null

# %% [markdown]
# ## Part 3c - We want to predict the wages for a player
# But the wages in the data frame are not a numerical type.  I have created a handy function that will take the amount and return a numerical value.  Create a new column by mapping the euro_converter function on the "Wage" column.

# %%
def euro_converter(string):
    unit = string[0:1]
    value = string[1:len(string)-1]
    multiplier = string[-1]
    if multiplier =="0": return 0
    
    # print(unit, value, multiplier)
    value = float(value)
    if multiplier=="M": value *= 1000000
    if multiplier=="K": value *= 1000
    return value

# %%
data["numericalWage"] = data["Wage"].map(euro_converter)
print(data["numericalWage"])
# Out:
# 0        565000.0
# 1        405000.0
# 2        290000.0
# 4        355000.0
# 5        340000.0
# 6        420000.0
# 7        455000.0
# 8        380000.0
# 10       205000.0
# 11       355000.0
# 12       125000.0
# 13       285000.0
# 14       225000.0
# 15       205000.0
# 16       205000.0
# 17       145000.0
# 20       315000.0
# 21       200000.0
# 23       300000.0
# 24       215000.0
# 25       100000.0
# 26       255000.0
# 27       285000.0
# 29       165000.0
# 30       315000.0
# 31       205000.0
# 32       340000.0
# 33       265000.0
# 34       160000.0
# 35       285000.0
#            ...
# 18171      1000.0
# 18173      1000.0
# 18174      1000.0
# 18175      1000.0
# 18176      1000.0
# 18177      1000.0
# 18179      1000.0
# 18181      1000.0
# 18182      1000.0
# 18184      1000.0
# 18185      1000.0
# 18186      1000.0
# 18187      1000.0
# 18188      1000.0
# 18189      1000.0
# 18190      1000.0
# 18191      1000.0
# 18192      1000.0
# 18193      1000.0
# ...

# %% [markdown]
# ## Part 4 - Split the data frame
#
# Use the train_test_split() function to split the data set into training(75%) and test(25%) sets.

# %%
from sklearn.model_selection import train_test_split

trainSet, testSet = train_test_split(data,test_size = .25, random_state= 123)
testSet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3686 entries, 14292 to 7588
# Data columns (total 88 columns):
# Unnamed: 0                  3686 non-null int64
# ID                          3686 non-null int64
# Name                        3686 non-null object
# Age                         3686 non-null int64
# Photo                       3686 non-null object
# Nationality                 3686 non-null object
# Flag                        3686 non-null object
# Overall                     3686 non-null int64
# Potential                   3686 non-null int64
# Club Logo                   3686 non-null object
# Value                       3686 non-null object
# Wage                        3686 non-null object
# Special                     3686 non-null int64
# Preferred Foot              3686 non-null object
# International Reputation    3686 non-null float64
# Weak Foot                   3686 non-null float64
# Skill Moves                 3686 non-null float64
# ...

# %% [markdown]
# ## Part 5 - Do some scatter plots
# Take a look at "Potential", "Overall", and the new wages feature you created.

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.scatter(x=data["Potential"], y=data["numericalWage"], marker = '^')
plt.scatter(x=data["Overall"], y=data["numericalWage"], marker = 'v')

# %% [markdown]
# ## Part 6 - Linear Regression
# 1. Pull out "Overall" for the X and the wage feature you created for y.
# 2. Fit the data.
# 3. Show R2 and Mean Square Error
# 4. Discuss the results

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
x = data[["Overall"]]
y = data["numericalWage"]

reg.fit(x,y)

bias = reg.intercept_
featureCoef = reg.coef_
print("the R2 score is : " + str(reg.score(x,y))) #this is the R2


from sklearn.metrics import mean_squared_error

yPrediction = reg.predict(x)
meanSquareError = mean_squared_error(y,yPrediction) #this is mse
print("mean squared error is : "+ str(meanSquareError))
# Out:
# the R2 score is : 0.33390974642384985
# mean squared error is : 347281860.93818104

# %% [markdown]
# Discussion:  the r2 is only at 33%. it is not great. Would like it to be closer to 100. the mean square error is really high. not sure what thats about

# %% [markdown]
# ## Part 7 - Add features to the Model
# 1. Pick up to 3 other features that you think might improve the model and use them for X.
# 2. Fit the data
# 3. Show the scores
# 4. Discuss the results

# %%
reg = LinearRegression()
x = data["Overall"]
y = data["International Reputation"]

reg.fit(x,y)

bias = reg.intercept_
featureCoef = reg.coef
print("the R2 score is : " + reg.score(x,y)) #this is the R2

yPrediction = reg.predict(x)
meanSquareError = mean_squared_error(y,yPrediction) #this is mse
print("mean squared error is : "+ meanSquareError)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-b70a1fd0de1b> in <module>
#       3 y = data["International Reputation"]
#       4
# ----> 5 reg.fit(x,y)
#       6
#       7 bias = reg.intercept_
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\base.py in fit(self, X, y, sample_weight)
#     456         n_jobs_ = self.n_jobs
#     457         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 458                          y_numeric=True, multi_output=True)
#     459
#     460         if sample_weight is not None and np.atleast_1d(sample_weight).ndim > 1:
#
# ...

# %%
reg = LinearRegression()
x = data["Overall"]
y = data["Age"]

reg.fit(x,y)

bias = reg.intercept_
featureCoef = reg.coef
print("the R2 score is : " + reg.score(x,y)) #this is the R2

yPrediction = reg.predict(x)
meanSquareError = mean_squared_error(y,yPrediction) #this is mse
print("mean squared error is : "+ meanSquareError)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-c9031e7bea9c> in <module>
#       3 y = data["Age"]
#       4
# ----> 5 reg.fit(x,y)
#       6
#       7 bias = reg.intercept_
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\base.py in fit(self, X, y, sample_weight)
#     456         n_jobs_ = self.n_jobs
#     457         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 458                          y_numeric=True, multi_output=True)
#     459
#     460         if sample_weight is not None and np.atleast_1d(sample_weight).ndim > 1:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
# ...

# %%
reg = LinearRegression()
x = data[["Overall"]]
y = data["Special"]

reg.fit(x,y)

bias = reg.intercept_
featureCoef = reg.coef_
print("the R2 score is : " + str(reg.score(x,y))) #this is the R2

yPrediction = reg.predict(x)
meanSquareError = mean_squared_error(y,yPrediction) #this is mse
print("mean squared error is : "+ meanSquareError)
# Out:
# the R2 score is : 0.6392264059631451
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-92cb31dda72a> in <module>
#      10
#      11 yPrediction = reg.predict(x)
# ---> 12 meanSquareError = mean_squared_error(y,yPrediction) #this is mse
#      13 print("mean squared error is : "+ meanSquareError)
#
# NameError: name 'mean_squared_error' is not defined

# %% [markdown]
# Discussion:

# %% [markdown]
# ## Part 8 - Test Set time
# Evaluate the model on the test set and discuss your results.

# %% [markdown]
# Discussion:

# %% [markdown]
# # Bonus options
# For each of the options, redo your regression using the new features, report the results and discuss.

# %% [markdown]
# 1. Do a better job of filtering the data.  It looks like there are 18159 instances that have numerical performance values.  Filter unneeded columns so that those 18159 instances remain.
# 2. Look at the other columns that contain objects and see if any could be useful in your regression.  Write a map function and apply.
# 2. Add in polynomial features.
